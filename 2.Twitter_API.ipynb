# %%
# create a developer account in twitter : https://developer.twitter.com/en
# steps are easy to follow and its free: [you will need to share a valid phone number to recieve OTP]

# follow these steps to create an app [ ignore the R code part ] : https://cran.r-project.org/web/packages/rtweet/vignettes/auth.html

# %%
api_key='OCxiixEgKLWtRpQKuf7n7VDKE'
api_key_secret='VCcR2dymwgLeUQZqakQawDvB42cPn11aLvQ4CjEYvJNt4HIIdI'
access_token='61981057-CHEcJ7b1L9M6sULGOL24L8dpJIWkud1BxQ6nZHsrP'
access_token_secret='qYlNxYUFhquwl74dJTqIbfUlFs0Idf6XfysPDhJfS2TTl'

# %%
import os
import tweepy as tw
import pandas as pd

# %%
auth = tw.OAuthHandler(api_key, api_key_secret)

auth.set_access_token(access_token, access_token_secret)

api = tw.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# ### Search twitter

# %%
search_words = "#machinelearning"
date_since = "2021-01-01" #yyyy-mm-dd

# %%
# this can be run repeatedly to fetch current data in every few seconds/min/hours [ for free accounts 
# there will be some rate limit from twitter backend]

# the current example gets 5 most recent tweets with the given search words
tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(5)
tweets

# %%
for tweet in tweets:
    print(tweet.text)
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in _error_catcher(self)
#     359             try:
# --> 360                 yield
#     361
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#
# ~/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#
# ~/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     490         # (for example, reading in 1k chunks)
# --> 491         n = self.fp.readinto(b)
#     492         if not n and b:
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
# --> 310                 raise timeout('The read operation timed out')
#     311             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in generate()
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     493             while not is_fp_closed(self._fp):
# --> 494                 data = self.read(amt=amt, decode_content=decode_content)
#     495
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     458                         # Content-Length are caught.
# --> 459                         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     460
#
# ~/anaconda3/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in _error_catcher(self)
#     364                 # there is yet no clean way to get at it from this context.
# --> 365                 raise ReadTimeoutError(self._pool, None, 'Read timed out.')
#     366
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     189                                                 auth=auth,
# --> 190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     685         if not stream:
# --> 686             r.content
#     687
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in content(self)
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in generate()
#     756                 except ReadTimeoutError as e:
# --> 757                     raise ConnectionError(e)
#     758             else:
#
# ConnectionError: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# TweepError                                Traceback (most recent call last)
# <ipython-input-6-4a32d1b7b3d3> in <module>
# ----> 1 for tweet in tweets:
#       2     print(tweet.text)
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in __next__(self)
#      49
#      50     def __next__(self):
# ---> 51         return self.next()
#      52
#      53     def next(self):
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     241         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     242             # Reached end of current page, get the next page...
# --> 243             self.current_page = self.page_iterator.next()
#     244             while len(self.current_page) == 0:
#     245                 self.current_page = self.page_iterator.next()
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     130
#     131         if self.index >= len(self.results) - 1:
# --> 132             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     133
#     134             if hasattr(self.method, '__self__'):
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     251                 return method
#     252             else:
# --> 253                 return method.execute()
#     254         finally:
#     255             method.session.close()
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
# --> 192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#     193
#     194                 rem_calls = resp.headers.get('x-rate-limit-remaining')
#
# ~/anaconda3/lib/python3.7/site-packages/six.py in reraise(tp, value, tb)
#     690                 value = tp()
#     691             if value.__traceback__ is not tb:
# --> 692                 raise value.with_traceback(tb)
#     693             raise value
#     694         finally:
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     188                                                 timeout=self.api.timeout,
#     189                                                 auth=auth,
# --> 190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
#     192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     684
#     685         if not stream:
# --> 686             r.content
#     687
#     688         return r
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in content(self)
#     826                 self._content = None
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#     830         self._content_consumed = True
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in generate()
#     755                     raise ContentDecodingError(e)
#     756                 except ReadTimeoutError as e:
# --> 757                     raise ConnectionError(e)
#     758             else:
#     759                 # Standard file-like object.
#
# TweepError: Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out.

# %% [markdown]
# ### remove retweets

# %%
new_search = search_words + " -filter:retweets"
new_search

# for detailed query writing : https://developer.twitter.com/en/docs/twitter-api/v1/rules-and-filtering/search-operators
# Out:
# '#machinelearning -filter:retweets'

# %%
tweets = tw.Cursor(api.search,
                       q=new_search,
                       lang="en",
                       since=date_since).items(5)

[tweet.text for tweet in tweets]
# Out:
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1621         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1622             raise WantReadError()
#    1623         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in _error_catcher(self)
#     359             try:
# --> 360                 yield
#     361
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#
# ~/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#
# ~/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     490         # (for example, reading in 1k chunks)
# --> 491         n = self.fp.readinto(b)
#     492         if not n and b:
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     311             else:
# --> 312                 return self.recv_into(*args, **kwargs)
#     313
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     311             else:
# --> 312                 return self.recv_into(*args, **kwargs)
#     313
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     311             else:
# --> 312                 return self.recv_into(*args, **kwargs)
#     313
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     309             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
# --> 310                 raise timeout('The read operation timed out')
#     311             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in generate()
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     493             while not is_fp_closed(self._fp):
# --> 494                 data = self.read(amt=amt, decode_content=decode_content)
#     495
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     458                         # Content-Length are caught.
# --> 459                         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     460
#
# ~/anaconda3/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in _error_catcher(self)
#     364                 # there is yet no clean way to get at it from this context.
# --> 365                 raise ReadTimeoutError(self._pool, None, 'Read timed out.')
#     366
#
# ReadTimeoutError: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     189                                                 auth=auth,
# --> 190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     685         if not stream:
# --> 686             r.content
#     687
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in content(self)
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in generate()
#     756                 except ReadTimeoutError as e:
# --> 757                     raise ConnectionError(e)
#     758             else:
#
# ConnectionError: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out.
#
# During handling of the above exception, another exception occurred:
#
# TweepError                                Traceback (most recent call last)
# <ipython-input-8-6e1334bd8657> in <module>
#       4                        since=date_since).items(5)
#       5
# ----> 6 [tweet.text for tweet in tweets]
#
# <ipython-input-8-6e1334bd8657> in <listcomp>(.0)
#       4                        since=date_since).items(5)
#       5
# ----> 6 [tweet.text for tweet in tweets]
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in __next__(self)
#      49
#      50     def __next__(self):
# ---> 51         return self.next()
#      52
#      53     def next(self):
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     241         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     242             # Reached end of current page, get the next page...
# --> 243             self.current_page = self.page_iterator.next()
#     244             while len(self.current_page) == 0:
#     245                 self.current_page = self.page_iterator.next()
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/cursor.py in next(self)
#     130
#     131         if self.index >= len(self.results) - 1:
# --> 132             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     133
#     134             if hasattr(self.method, '__self__'):
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     251                 return method
#     252             else:
# --> 253                 return method.execute()
#     254         finally:
#     255             method.session.close()
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
# --> 192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#     193
#     194                 rem_calls = resp.headers.get('x-rate-limit-remaining')
#
# ~/anaconda3/lib/python3.7/site-packages/six.py in reraise(tp, value, tb)
#     690                 value = tp()
#     691             if value.__traceback__ is not tb:
# --> 692                 raise value.with_traceback(tb)
#     693             raise value
#     694         finally:
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/binder.py in execute(self)
#     188                                                 timeout=self.api.timeout,
#     189                                                 auth=auth,
# --> 190                                                 proxies=self.api.proxy)
#     191                 except Exception as e:
#     192                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     684
#     685         if not stream:
# --> 686             r.content
#     687
#     688         return r
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in content(self)
#     826                 self._content = None
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#     830         self._content_consumed = True
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in generate()
#     755                     raise ContentDecodingError(e)
#     756                 except ReadTimeoutError as e:
# --> 757                     raise ConnectionError(e)
#     758             else:
#     759                 # Standard file-like object.
#
# TweepError: Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Read timed out.

# %% [markdown]
# ### users and their locations

# %%
tweets = tw.Cursor(api.search,
                       q=new_search,
                       lang="en",
                       since=date_since).items(5)
users_locs = [[tweet.user.screen_name, tweet.user.location] for tweet in tweets]
users_locs

# %% [markdown]
# ### multiple terms search

# %%
new_search = "python+keras -filter:retweets"

tweets = tw.Cursor(api.search,
                   q=new_search,
                   lang="en",
                   since='2018-01-01').items(1000)

all_tweets = [tweet.text for tweet in tweets]
all_tweets[:5]

# %% [markdown]
# ### Trend

# %%
api.trends_available()

# returns places names with woeid [yahoo where on earth id]

# search woeid for your place of interest here : https://www.findmecity.com

# %%
api.trends_place(2295414) # this is woeid for hyderabad

# Global information is available by using 1 as the WOEID
# The tweet_volume for the last 24 hours is also returned for many trends if this is available.
# exclude – Setting this equal to hashtags will remove all hashtags from the trends list.
# Out:
# [{'trends': [{'name': '#InternationalDayOfHappiness',
#     'url': 'http://twitter.com/search?q=%23InternationalDayOfHappiness',
#     'promoted_content': None,
#     'query': '%23InternationalDayOfHappiness',
#     'tweet_volume': 53395},
#    {'name': '#WorldHappinessDay',
#     'url': 'http://twitter.com/search?q=%23WorldHappinessDay',
#     'promoted_content': None,
#     'query': '%23WorldHappinessDay',
#     'tweet_volume': None},
#    {'name': '#KarnanTeaser',
#     'url': 'http://twitter.com/search?q=%23KarnanTeaser',
#     'promoted_content': None,
#     'query': '%23KarnanTeaser',
#     'tweet_volume': 87717},
#    {'name': '#WorldSparrowDay',
#     'url': 'http://twitter.com/search?q=%23WorldSparrowDay',
#     'promoted_content': None,
#     'query': '%23WorldSparrowDay',
#     'tweet_volume': 15732},
#    {'name': '#ModimoyAsom',
#     'url': 'http://twitter.com/search?q=%23ModimoyAsom',
#     'promoted_content': None,
#     'query': '%23ModimoyAsom',
#     'tweet_volume': None},
#    {'name': 'राष्ट्रीय स्वयंसेवक संघ',
#     'url': 'http://twitter.com/search?q=%22%E0%A4%B0%E0%A4%BE%E0%A4%B7%E0%A5%8D%E0%A4%9F%E0%A5%8D%E0%A4%B0%E0%A5%80%E0%A4%AF+%E0%A4%B8%E0%A5%8D%E0%A4%B5%E0%A4%AF%E0%A4%82%E0%A4%B8%E0%A5%87%E0%A4%B5%E0%A4%95+%E0%A4%B8%E0%A4%82%E0%A4%98%22',
#     'promoted_content': None,
#     'query': '%22%E0%A4%B0%E0%A4%BE%E0%A4%B7%E0%A5%8D%E0%A4%9F%E0%A5%8D%E0%A4%B0%E0%A5%80%E0%A4%AF+%E0%A4%B8%E0%A5%8D%E0%A4%B5%E0%A4%AF%E0%A4%82%E0%A4%B8%E0%A5%87%E0%A4%B5%E0%A4%95+%E0%A4%B8%E0%A4%82%E0%A4%98%22',
#     'tweet_volume': None},
#    {'name': 'श्री दत्तात्रेय',
#     'url': 'http://twitter.com/search?q=%22%E0%A4%B6%E0%A5%8D%E0%A4%B0%E0%A5%80+%E0%A4%A6%E0%A4%A4%E0%A5%8D%E0%A4%A4%E0%A4%BE%E0%A4%A4%E0%A5%8D%E0%A4%B0%E0%A5%87%E0%A4%AF%22',
#     'promoted_content': None,
#     'query': '%22%E0%A4%B6%E0%A5%8D%E0%A4%B0%E0%A5%80+%E0%A4%A6%E0%A4%A4%E0%A5%8D%E0%A4%A4%E0%A4%BE%E0%A4%A4%E0%A5%8D%E0%A4%B0%E0%A5%87%E0%A4%AF%22',
#     'tweet_volume': None},
#    {'name': 'अखिल भारतीय प्रतिनिधि सभा',
#     'url': 'http://twitter.com/search?q=%22%E0%A4%85%E0%A4%96%E0%A4%BF%E0%A4%B2+%E0%A4%AD%E0%A4%BE%E0%A4%B0%E0%A4%A4%E0%A5%80%E0%A4%AF+%E0%A4%AA%E0%A5%8D%E0%A4%B0%E0%A4%A4%E0%A4%BF%E0%A4%A8%E0%A4%BF%E0%A4%A7%E0%A4%BF+%E0%A4%B8%E0%A4%AD%E0%A4%BE%22',
#     'promoted_content': None,
#     'query': '%22%E0%A4%85%E0%A4%96%E0%A4%BF%E0%A4%B2+%E0%A4%AD%E0%A4%BE%E0%A4%B0%E0%A4%A4%E0%A5%80%E0%A4%AF+%E0%A4%AA%E0%A5%8D%E0%A4%B0%E0%A4%A4%E0%A4%BF%E0%A4%A8%E0%A4%BF%E0%A4%A7%E0%A4%BF+%E0%A4%B8%E0%A4%AD%E0%A4%BE%22',
#     'tweet_volume': None},
#    {'name': 'RAMA RAJU aRRRiving',
#     'url': 'http://twitter.com/search?q=%22RAMA+RAJU+aRRRiving%22',
#     'promoted_content': None,
#     'query': '%22RAMA+RAJU+aRRRiving%22',
#     'tweet_volume': 15102},
#    {'name': 'Vimal',
#     'url': 'http://twitter.com/search?q=Vimal',
#     'promoted_content': None,
#     'query': 'Vimal',
#     'tweet_volume': 12707},
#    {'name': 'cbi expose jiah killers',
#     'url': 'http://twitter.com/search?q=%22cbi+expose+jiah+killers%22',
#     'promoted_content': None,
#     'query': '%22cbi+expose+jiah+killers%22',
#     'tweet_volume': 51977},
#    {'name': 'BANGLADESH ROARS 4 SSR',
#     'url': 'http://twitter.com/search?q=%22BANGLADESH+ROARS+4+SSR%22',
#     'promoted_content': None,
#     'query': '%22BANGLADESH+ROARS+4+SSR%22',
#     'tweet_volume': 24586},
#    {'name': 'MLRIT College',
#     'url': 'http://twitter.com/search?q=%22MLRIT+College%22',
#     'promoted_content': None,
#     'query': '%22MLRIT+College%22',
#     'tweet_volume': 14752},
#    {'name': 'wooyoung',
#     'url': 'http://twitter.com/search?q=wooyoung',
#     'promoted_content': None,
#     'query': 'wooyoung',
#     'tweet_volume': 26890},
#    {'name': 'Kharagpur',
#     'url': 'http://twitter.com/search?q=Kharagpur',
#     'promoted_content': None,
#     'query': 'Kharagpur',
#     'tweet_volume': 48120},
#    {'name': 'Toufeek Ahmed',
#     'url': 'http://twitter.com/search?q=%22Toufeek+Ahmed%22',
#     'promoted_content': None,
#     'query': '%22Toufeek+Ahmed%22',
#     'tweet_volume': 11592},
#    {'name': 'Jinyoung',
#     'url': 'http://twitter.com/search?q=Jinyoung',
#     'promoted_content': None,
#     'query': 'Jinyoung',
#     'tweet_volume': 77629},
#    {'name': 'Ramos',
#     'url': 'http://twitter.com/search?q=Ramos',
#     'promoted_content': None,
#     'query': 'Ramos',
#     'tweet_volume': 78850},
#    {'name': 'Parsi',
#     'url': 'http://twitter.com/search?q=Parsi',
#     'promoted_content': None,
#     'query': 'Parsi',
#     'tweet_volume': None},
#    {'name': 'General Secretary',
#     'url': 'http://twitter.com/search?q=%22General+Secretary%22',
#     'promoted_content': None,
#     'query': '%22General+Secretary%22',
#     'tweet_volume': 10732},
#    {'name': 'Mansukh Hiren',
#     'url': 'http://twitter.com/search?q=%22Mansukh+Hiren%22',
#     'promoted_content': None,
#     'query': '%22Mansukh+Hiren%22',
#     'tweet_volume': None},
#    {'name': 'Finland',
#     'url': 'http://twitter.com/search?q=Finland',
#     'promoted_content': None,
#     'query': 'Finland',
#     'tweet_volume': 32793},
#    {'name': 'Dogs',
#     'url': 'http://twitter.com/search?q=Dogs',
#     'promoted_content': None,
#     'query': 'Dogs',
#     'tweet_volume': 109068},
#    {'name': 'PETA',
#     'url': 'http://twitter.com/search?q=PETA',
#     'promoted_content': None,
#     'query': 'PETA',
#     'tweet_volume': 16062},
#    {'name': 'Odia',
#     'url': 'http://twitter.com/search?q=Odia',
#     'promoted_content': None,
#     'query': 'Odia',
#     'tweet_volume': 12762},
#    {'name': 'sufiscore atifaslamsong',
#     'url': 'http://twitter.com/search?q=%22sufiscore+atifaslamsong%22',
#     'promoted_content': None,
#     'query': '%22sufiscore+atifaslamsong%22',
#     'tweet_volume': None},
#    {'name': '23rd March',
#     'url': 'http://twitter.com/search?q=%2223rd+March%22',
#     'promoted_content': None,
#     'query': '%2223rd+March%22',
#     'tweet_volume': 37044},
#    {'name': 'ISIS',
#     'url': 'http://twitter.com/search?q=ISIS',
#     'promoted_content': None,
#     'query': 'ISIS',
#     'tweet_volume': 19045},
#    {'name': 'CCTV',
#     'url': 'http://twitter.com/search?q=CCTV',
#     'promoted_content': None,
#     'query': 'CCTV',
#     'tweet_volume': 40920},
#    {'name': 'Holi',
#     'url': 'http://twitter.com/search?q=Holi',
#     'promoted_content': None,
#     'query': 'Holi',
#     'tweet_volume': 22084},
#    {'name': 'Lloyd Austin',
#     'url': 'http://twitter.com/search?q=%22Lloyd+Austin%22',
#     'promoted_content': None,
#     'query': '%22Lloyd+Austin%22',
#     'tweet_volume': 11710},
#    {'name': 'Dalits',
#     'url': 'http://twitter.com/search?q=Dalits',
#     'promoted_content': None,
#     'query': 'Dalits',
#     'tweet_volume': None},
#    {'name': 'Aadhar',
#     'url': 'http://twitter.com/search?q=Aadhar',
#     'promoted_content': None,
#     'query': 'Aadhar',
#     'tweet_volume': None},
#    {'name': 'New Delhi',
#     'url': 'http://twitter.com/search?q=%22New+Delhi%22',
#     'promoted_content': None,
#     'query': '%22New+Delhi%22',
#     'tweet_volume': None},
#    {'name': '#MicromaxIN1',
#     'url': 'http://twitter.com/search?q=%23MicromaxIN1',
#     'promoted_content': None,
#     'query': '%23MicromaxIN1',
#     'tweet_volume': None},
#    {'name': '#आदिवासी_हिंदू_है',
#     'url': 'http://twitter.com/search?q=%23%E0%A4%86%E0%A4%A6%E0%A4%BF%E0%A4%B5%E0%A4%BE%E0%A4%B8%E0%A5%80_%E0%A4%B9%E0%A4%BF%E0%A4%82%E0%A4%A6%E0%A5%82_%E0%A4%B9%E0%A5%88',
#     'promoted_content': None,
#     'query': '%23%E0%A4%86%E0%A4%A6%E0%A4%BF%E0%A4%B5%E0%A4%BE%E0%A4%B8%E0%A5%80_%E0%A4%B9%E0%A4%BF%E0%A4%82%E0%A4%A6%E0%A5%82_%E0%A4%B9%E0%A5%88',
#     'tweet_volume': 23395},
#    {'name': '#YuvarathnaaTrailer',
#     'url': 'http://twitter.com/search?q=%23YuvarathnaaTrailer',
#     'promoted_content': None,
#     'query': '%23YuvarathnaaTrailer',
#     'tweet_volume': 12272},
#    {'name': '#ModirSatheiAsolPoriborton',
#     'url': 'http://twitter.com/search?q=%23ModirSatheiAsolPoriborton',
#     'promoted_content': None,
#     'query': '%23ModirSatheiAsolPoriborton',
#     'tweet_volume': 171373},
#    {'name': '#VakeelSaabMusicalFest',
#     'url': 'http://twitter.com/search?q=%23VakeelSaabMusicalFest',
#     'promoted_content': None,
#     'query': '%23VakeelSaabMusicalFest',
#     'tweet_volume': 19493},
#    {'name': '#PakhalaDibasa',
#     'url': 'http://twitter.com/search?q=%23PakhalaDibasa',
#     'promoted_content': None,
#     'query': '%23PakhalaDibasa',
#     'tweet_volume': None},
#    {'name': '#DattatreyaHosabale',
#     'url': 'http://twitter.com/search?q=%23DattatreyaHosabale',
#     'promoted_content': None,
#     'query': '%23DattatreyaHosabale',
#     'tweet_volume': None},
#    {'name': '#Reservation',
#     'url': 'http://twitter.com/search?q=%23Reservation',
#     'promoted_content': None,
#     'query': '%23Reservation',
#     'tweet_volume': None},
#    {'name': '#SeethaRAMaRajuCHARAN',
#     'url': 'http://twitter.com/search?q=%23SeethaRAMaRajuCHARAN',
#     'promoted_content': None,
#     'query': '%23SeethaRAMaRajuCHARAN',
#     'tweet_volume': 17834},
#    {'name': '#आदिवासी_हिंदू_नहीं_है',
#     'url': 'http://twitter.com/search?q=%23%E0%A4%86%E0%A4%A6%E0%A4%BF%E0%A4%B5%E0%A4%BE%E0%A4%B8%E0%A5%80_%E0%A4%B9%E0%A4%BF%E0%A4%82%E0%A4%A6%E0%A5%82_%E0%A4%A8%E0%A4%B9%E0%A5%80%E0%A4%82_%E0%A4%B9%E0%A5%88',
#     'promoted_content': None,
#     'query': '%23%E0%A4%86%E0%A4%A6%E0%A4%BF%E0%A4%B5%E0%A4%BE%E0%A4%B8%E0%A5%80_%E0%A4%B9%E0%A4%BF%E0%A4%82%E0%A4%A6%E0%A5%82_%E0%A4%A8%E0%A4%B9%E0%A5%80%E0%A4%82_%E0%A4%B9%E0%A5%88',
#     'tweet_volume': None},
#    {'name': '#AssamWithRahulGandhi',
#     'url': 'http://twitter.com/search?q=%23AssamWithRahulGandhi',
#     'promoted_content': None,
#     'query': '%23AssamWithRahulGandhi',
#     'tweet_volume': None},
#    {'name': '#ପଖାଳଦିବସ',
#     'url': 'http://twitter.com/search?q=%23%E0%AC%AA%E0%AC%96%E0%AC%BE%E0%AC%B3%E0%AC%A6%E0%AC%BF%E0%AC%AC%E0%AC%B8',
#     'promoted_content': None,
#     'query': '%23%E0%AC%AA%E0%AC%96%E0%AC%BE%E0%AC%B3%E0%AC%A6%E0%AC%BF%E0%AC%AC%E0%AC%B8',
#     'tweet_volume': None},
#    {'name': '#MiddleClassKeBureDin',
#     'url': 'http://twitter.com/search?q=%23MiddleClassKeBureDin',
#     'promoted_content': None,
#     'query': '%23MiddleClassKeBureDin',
#     'tweet_volume': 23214},
#    {'name': '#lockdown2021',
#     'url': 'http://twitter.com/search?q=%23lockdown2021',
#     'promoted_content': None,
#     'query': '%23lockdown2021',
#     'tweet_volume': 24488},
#    {'name': '#NavrozMubarak',
#     'url': 'http://twitter.com/search?q=%23NavrozMubarak',
#     'promoted_content': None,
#     'query': '%23NavrozMubarak',
#     'tweet_volume': None},
#    {'name': '#ChopraOnOprah',
#     'url': 'http://twitter.com/search?q=%23ChopraOnOprah',
#     'promoted_content': None,
#     'query': '%23ChopraOnOprah',
#     'tweet_volume': None}],
#   'as_of': '2021-03-20T09:53:35Z',
#   'created_at': '2021-03-19T07:33:51Z',
#   'locations': [{'name': 'Hyderabad', 'woeid': 2295414}]}]

# %%
api.trends_place(2295414,exclude='#WhatsAppDown')

# %%
# detailed api docs : https://tweepy.readthedocs.io
# gives you options for managing your twitter acount with a script

# %% [markdown]
# ### other notable data sources with an API offering
#
# * https://www.reddit.com/dev/api/   [reddit ]
# * https://api.stackexchange.com/docs  [stackoverflow]
# * https://api.stackexchange.com/docs  [Facebook ]
